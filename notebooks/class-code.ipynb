# %%
# !pip install pandas
# Out:
# ...
#   WARNING: The script f2py.exe is installed in 'C:\Users\tyler\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: C:\Users\tyler\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.7 MB 1.1 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/10.7 MB 1.1 MB/s eta 0:00:10
#       --------------------------------------- 0.2/10.7 MB 1.2 MB/s eta 0:00:10
# ...

# %% [markdown]
# Day 2

# %%
import pandas as pd 

df = pd.read_csv("../data/insurance.csv")

df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       4 df = pd.read_csv("../data/insurance.csv")
#       6 df
#
# ModuleNotFoundError: No module named 'pandas'
